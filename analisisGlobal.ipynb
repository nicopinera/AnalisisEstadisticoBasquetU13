# %% [markdown]
# # Analisis estadistico Categoria U13
# En la presente Notebook se generara el estudio de las estadisticas para todos los equipos que pasaron el 2025 por la categoria A1

# %% [markdown]
# ## Librerias y funciones utilizadas
# Ignorar esta seccion

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('./Funciones')

# %%
import top20

# %% [markdown]
# ---

# %% [markdown]
# # Estadisticas convencionales

# %% [markdown]
# ## Maximos Goleadores

# %%
top20.top_20_jugadores_puntos('EstadisticasGlobales.csv')
# Out:
#                                 Jugador              Club  Partidos Jugados  \
# 1            LOZA DIAZ, ARTURO BAUTISTA             Pesca                20
# 2                  DI RIENZO, JUAN CRUZ       Santo Tomas                20
# 3   LEDESMA SPILERE , JOAQUIN LEONARDO            Empalme                29
# 4           NAZARALA SASTRE, JUAN PABLO       Santo Tomas                30
# 5                         SONA, FACUNDO  Banco de Cordoba                20
# 6                       OBERTI, FACUNDO             Banco                27
# 7              DA VIA, GENARO FRANCESCO             Pesca                35
# 8                    FELSZTYNA, AGUSTIN       Macabi-Noar                21
# 9          GONZALEZ SCHIEBEL, FRANCISCO     Poeta Lugones                28
# 10                  VALDES, TOMAS SIMON     Universitario                36
# 11                  MASQUIJO, FRANCISCO   Dante Alighieri                18
# ...

# %% [markdown]
# ## Maixmos Asistidores

# %%
top20.top_20_asistidores('EstadisticasGlobales.csv')
# Out:
#                               Jugador              Club  Partidos Jugados  \
# 1                 VALDES, TOMAS SIMON     Universitario                36
# 2          MARTINEZ ZAMORA, VALENTINO  Banco de Cordoba                21
# 3                       SONA, FACUNDO  Banco de Cordoba                20
# 4                     OBERTI, FACUNDO             Banco                27
# 5                     LUKACH, BENICIO             Pesca                34
# 6            DA VIA, GENARO FRANCESCO             Pesca                35
# 7                DI RIENZO, JUAN CRUZ       Santo Tomas                20
# 8        GONZALEZ SCHIEBEL, FRANCISCO     Poeta Lugones                28
# 9                   BRANDAN, SANTIAGO     Universitario                22
# 10            ACEVEDO, PABLO EZEQUIEL     Universitario                31
# 11                     RIVETTA, LUCAS             Pesca                35
# 12          MATTOS MANASSERO, TIZIANO             Pesca                22
# ...

# %% [markdown]
# ## Maximos en Faltas

# %%
top20.top_20_faltas('EstadisticasGlobales.csv')
# Out:
#                                 Jugador             Club  Partidos Jugados  \
# 1                   VALDES, TOMAS SIMON    Universitario                36
# 2    ALLENDE BORDOLINI, FRANCESCA SOFÍA    Universitario                29
# 3   LEDESMA SPILERE , JOAQUIN LEONARDO           Empalme                29
# 4                       RIZZO, VALENTIN    Universitario                36
# 5                    FELSZTYNA, AGUSTIN      Macabi-Noar                21
# 6           NAZARALA SASTRE, JUAN PABLO      Santo Tomas                30
# 7                       OBERTI, FACUNDO            Banco                27
# 8                   OLIVERA ROQUE, CIRO      Santo Tomas                20
# 9                  DI RIENZO, JUAN CRUZ      Santo Tomas                20
# 10     RAPETTI PERALTA, TIAGO BENJAMIN           Empalme                17
# 11                      LUKACH, BENICIO            Pesca                34
# ...

# %% [markdown]
# ## Maximo Anotadores

# %% [markdown]
# ### Maximo anotador de 2 puntos

# %%
top20.top_20_t2c('EstadisticasGlobales.csv')
# Out:
#                                       Jugador              Club  \
# 1                  LOZA DIAZ, ARTURO BAUTISTA             Pesca
# 2         LEDESMA SPILERE , JOAQUIN LEONARDO            Empalme
# 3                             OBERTI, FACUNDO             Banco
# 4                               SONA, FACUNDO  Banco de Cordoba
# 5                        DI RIENZO, JUAN CRUZ       Santo Tomas
# 6                    DA VIA, GENARO FRANCESCO             Pesca
# 7                          FELSZTYNA, AGUSTIN       Macabi-Noar
# 8                     MARTINEZ ROSSI, LAUTARO             Pesca
# 9                 NAZARALA SASTRE, JUAN PABLO       Santo Tomas
# 10                GUZMAN, LAUTARO MAXIMILIANO             Pesca
# 11               GONZALEZ SCHIEBEL, FRANCISCO     Poeta Lugones
# 12  LICARI RODRIGUEZ CUSCUETA, AGUSTIN JAVIER       Santo Tomas
# 13                  MATTOS MANASSERO, TIZIANO             Pesca
# 14                        VALDES, TOMAS SIMON     Universitario
# ...

# %% [markdown]
# ### Maximos anotadores de 3 puntos

# %%
top20.top_20_t3c('EstadisticasGlobales.csv')
# Out:
#                                 Jugador              Club  Partidos Jugados  \
# 1           NAZARALA SASTRE, JUAN PABLO       Santo Tomas                30
# 2                     ESPINOSA, IGNACIO     Universitario                32
# 3                  DI RIENZO, JUAN CRUZ       Santo Tomas                20
# 4                KAPLINSKY , MANU DAVID       Macabi-Noar                20
# 5                   MASQUIJO, FRANCISCO   Dante Alighieri                18
# 6      VALENTINO FAZZIO, LEANDRO DANIEL           Empalme                28
# 7                     TAY TOSCO, FELIPE       Santo Tomas                20
# 8                       LUKACH, BENICIO             Pesca                34
# 9            LOZA DIAZ, ARTURO BAUTISTA             Pesca                20
# 10                    BRANDAN, SANTIAGO     Universitario                22
# 11           MARTINEZ ZAMORA, VALENTINO  Banco de Cordoba                21
# ...

# %% [markdown]
# ### Maximos Anotadores de Tiros Libres

# %%
top20.top_20_t1c('EstadisticasGlobales.csv')
# Out:
#                                 Jugador              Club  Partidos Jugados  \
# 1            LOZA DIAZ, ARTURO BAUTISTA             Pesca                20
# 2           NAZARALA SASTRE, JUAN PABLO       Santo Tomas                30
# 3                   MASQUIJO, FRANCISCO   Dante Alighieri                18
# 4   LEDESMA SPILERE , JOAQUIN LEONARDO            Empalme                29
# 5        LEANZA AGUILERA, MATIAS LEONEL           Empalme                30
# 6                         SONA, FACUNDO  Banco de Cordoba                20
# 7          GONZALEZ SCHIEBEL, FRANCISCO     Poeta Lugones                28
# 8                    FELSZTYNA, AGUSTIN       Macabi-Noar                21
# 9                  DI RIENZO, JUAN CRUZ       Santo Tomas                20
# 10                    GIOVETTI, OCTAVIO             Pilar                12
# 11                       RIVETTA, LUCAS             Pesca                35
# ...

# %% [markdown]
# ## Maximo Reboteadores

# %%
top20.top_20_rd('EstadisticasGlobales.csv')
# Out:
#                                       Jugador              Club  \
# 1                         VALDES, TOMAS SIMON     Universitario
# 2                           ESPINOSA, IGNACIO     Universitario
# 3                    DA VIA, GENARO FRANCESCO             Pesca
# 4         LEDESMA SPILERE , JOAQUIN LEONARDO            Empalme
# 5                    ONORES RODRIGUEZ, JULIAN             Pilar
# 6     AGUIRRE FARIAS DE LA TORRE, MAXIMO LUIS       Santo Tomas
# 7                          FELSZTYNA, AGUSTIN       Macabi-Noar
# 8                              RIVETTA, LUCAS             Pesca
# 9                               SONA, FACUNDO  Banco de Cordoba
# 10                   GOMEZ MACHNOWSKY, FELIPE       Santo Tomas
# 11                        FARÍAS, BRUNO MATEO     Universitario
# 12                            OBERTI, FACUNDO             Banco
# 13           FERREYRA CURA, SANTINO SEBASTIAN     Poeta Lugones
# 14                            MUÑOZ, PATRICIO   Union Electrica
# ...

# %%
top20.top_20_ro('EstadisticasGlobales.csv')
# Out:
#                                       Jugador              Club  \
# 1                    DA VIA, GENARO FRANCESCO             Pesca
# 2                    CORONEL TAMAYO, JERONIMO             Pesca
# 3                             LUKACH, BENICIO             Pesca
# 4   LICARI RODRIGUEZ CUSCUETA, AGUSTIN JAVIER       Santo Tomas
# 5                    GOMEZ MACHNOWSKY, FELIPE       Santo Tomas
# 6                              RIVETTA, LUCAS             Pesca
# 7                             OBERTI, FACUNDO             Banco
# 8                 GUZMAN, LAUTARO MAXIMILIANO             Pesca
# 9               FERNANDEZ ECHEVESTE, LEONIDAS  Banco de Cordoba
# 10                        VALDES, TOMAS SIMON     Universitario
# 11                        FARÍAS, BRUNO MATEO     Universitario
# 12                          COVASSI, FEDERICO  Banco de Cordoba
# 13        LEDESMA SPILERE , JOAQUIN LEONARDO            Empalme
# 14                  PAREDES BRIZUELA, SANTINO             Pesca
# ...

# %%
top20.top_20_rt('EstadisticasGlobales.csv')
# Out:
#                                       Jugador              Club  \
# 1                    DA VIA, GENARO FRANCESCO             Pesca
# 2                         VALDES, TOMAS SIMON     Universitario
# 3         LEDESMA SPILERE , JOAQUIN LEONARDO            Empalme
# 4                              RIVETTA, LUCAS             Pesca
# 5                    GOMEZ MACHNOWSKY, FELIPE       Santo Tomas
# 6                           ESPINOSA, IGNACIO     Universitario
# 7                             OBERTI, FACUNDO             Banco
# 8   LICARI RODRIGUEZ CUSCUETA, AGUSTIN JAVIER       Santo Tomas
# 9     AGUIRRE FARIAS DE LA TORRE, MAXIMO LUIS       Santo Tomas
# 10                              SONA, FACUNDO  Banco de Cordoba
# 11                        FARÍAS, BRUNO MATEO     Universitario
# 12                   ONORES RODRIGUEZ, JULIAN             Pilar
# 13                   CORONEL TAMAYO, JERONIMO             Pesca
# 14                         FELSZTYNA, AGUSTIN       Macabi-Noar
# ...

# %% [markdown]
# ## Maximos Recuperos

# %%
top20.top_20_recuperos('EstadisticasGlobales.csv')
# Out:
#                                     Jugador             Club  \
# 1                       VALDES, TOMAS SIMON    Universitario
# 2                           SUAREZ, FACUNDO    Poeta Lugones
# 3                       MASQUIJO, FRANCISCO  Dante Alighieri
# 4                           LUKACH, BENICIO            Pesca
# 5               NAZARALA SASTRE, JUAN PABLO      Santo Tomas
# 6              GONZALEZ SCHIEBEL, FRANCISCO    Poeta Lugones
# 7                         BRANDAN, SANTIAGO    Universitario
# 8                  DA VIA, GENARO FRANCESCO            Pesca
# 9   AGUIRRE FARIAS DE LA TORRE, MAXIMO LUIS      Santo Tomas
# 10                       FELSZTYNA, AGUSTIN      Macabi-Noar
# 11         FERREYRA CURA, SANTINO SEBASTIAN    Poeta Lugones
# 12                    BURGOS MEALLA , BRUNO  Dante Alighieri
# 13      LEDESMA SPILERE , JOAQUIN LEONARDO           Empalme
# 14                          OBERTI, FACUNDO            Banco
# ...
